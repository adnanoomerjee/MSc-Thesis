# %%
import sys

sys.path.append("/nfs/nhome/live/aoomerjee/MSc-Thesis/")

import matplotlib.pyplot as plt
from pathlib import Path
from hct.io.model import load, save
import pandas as pd
import jax.numpy as jp
import jax
import importlib.util
import re
from typing import Literal
import seaborn as sns

def extract_date_time_from_log(log_file_path):
    """
    Extracts the date and time from the first line of the given log file.
    
    Args:
    - log_file_path (str): Path to the log file.

    Returns:
    - str: Date and time from the first log line, or None if not found.
    """
    with open(log_file_path, 'r') as file:
        first_line = file.readline()
        
        # Extract date and time using regex
        match = re.search(r'I(\d{2})(\d{2}) (\d{2}:\d{2}:\d{2}.\d{6})', first_line)
        if match:
            month, day, time = match.groups()
            date_str = f"{month}/{day} {time}"
            return date_str
    return None

def import_function_from_path(path, function_name):
    spec = importlib.util.spec_from_file_location("__temp_module__", path)
    module = importlib.util.module_from_spec(spec)
    spec.loader.exec_module(module)
    return getattr(module, function_name)


def get_training_metrics(modelpath):
    
    training_metrics = load(f"{modelpath}/training_metrics")
    training_metrics.pop('model_variant_name')

    training_steps = []
    metrics_per_training_step = []

    for k, v in training_metrics.items():
        training_steps.append(float(k))
        metrics_per_training_step.append(v)

    metrics_per_training_step[0].update(
      {'training/sps': 0.0, 
      'training/walltime': 0.0, 
      'training/entropy_loss': 0.0, 
      'training/policy_loss': 0.0, 
      'training/total_loss': 0.0, 
      'training/v_loss': 0.0
      }
    )

    return (training_steps, metrics_per_training_step)

def plot(data: tuple, 
         metric: str, 
         error: Literal[None, 'std', 'stderr'] = None, 
         label = None, 
         err_label = None, 
         xlabel = None, 
         ylabel = None,
         xlim = None,
         ylim = None,
         ax = None
        ):
  
  
  steps, metrics = data
  max_steps = steps[-1]

  values = []
  lower_error = []
  upper_error = []
     
  
  for m in metrics:
    value = m[metric]['mean']
    if metric == 'eval/episode_distance_to_end':
       value = 22 - value
    err = m[metric][error]
    values.append(value)
    lower_error.append(value - err)
    upper_error.append(value + err)

  xlim = (0, max_steps) if xlim is None else xlim

  if ax == None:
     ax = plt
  
  ax.set_xlabel(xlabel)
  ax.set_ylabel(ylabel)

  ax.set_xlim(xlim)
  ax.set_ylim(ylim)
  
  ax.plot(steps, values, linewidth=0.5, label=label)
  if error is not None:
    ax.fill_between(steps, lower_error , upper_error , alpha=0.3, label=err_label) 



pd.set_option('display.max_columns', None)

# %%
hyperparam_sweeps = Path("/nfs/nhome/live/aoomerjee/MSc-Thesis/hct/training/hyperparam_sweeps_v3")

hma_filepath = hyperparam_sweeps / "hma"
hurdles_filepath = hyperparam_sweeps / "hurdles"
gaps_filepath = hyperparam_sweeps / "gaps"
maze_filepath = hyperparam_sweeps / "maze"

filepaths = [hma_filepath, hurdles_filepath, gaps_filepath, maze_filepath]

def generate_data_tables():

    data = []
    
    for i, filepath in enumerate(filepaths):

        environment_name = filepath.name
        if environment_name == 'hma':
            steps = 150_000_000
        else:
            steps = 50_000_000

        for j, model in enumerate(filepath.iterdir()):

            model_category = model.name

            if model.is_dir() and not (environment_name.startswith('__') or environment_name.startswith('.')):
                runs = model / 'runs'
                hyperparameter_sweep = import_function_from_path(model / 'run.py', 'hyperparameter_sweep')
                env_params, training_params = hyperparameter_sweep()
                
                for run in runs.iterdir():

                    model_variant = run.name

                    if (run / 'network').exists() and int(model_variant) < len(env_params):

                        date = extract_date_time_from_log(run / 'log.INFO')

                        training_metrics = load(f'{run}/training_metrics')
                        env = load(f'{run}/env')

                        env_params[int(model_variant)].pop('architecture_configs')

                        final_metrics = {'date':date, 'model': model_category, 'environment': environment_name, 'model_variant_id': model_variant, 'modelpath': run}
                        final_metrics.update(env_params[int(model_variant)])
                        if 'low_level_modelpath' in final_metrics.keys():
                            low_level_model_name = int(Path(final_metrics['low_level_modelpath']).name)
                            low_level_env_params, _ = import_function_from_path(Path(final_metrics['low_level_modelpath']).parent.parent / 'run.py', 'hyperparameter_sweep')()
                            final_metrics['low_level_modelpath'] = low_level_model_name
                            final_metrics['position_goals'] = low_level_env_params[low_level_model_name]['position_goals']
                            final_metrics['velocity_goals'] = low_level_env_params[low_level_model_name]['velocity_goals']
                            final_metrics['goal_dist'] = low_level_env_params[low_level_model_name]['goal_dist']
                            final_metrics['distance_reward'] = low_level_env_params[low_level_model_name]['distance_reward']
                            final_metrics['goal_importance'] = low_level_env_params[low_level_model_name]['goal_importance']
                            final_metrics['low_level_goal_repeat'] = env.action_repeat
                        elif 'mid_level_modelpath' in final_metrics.keys():
                            mid_level_model_name = int(Path(final_metrics['mid_level_modelpath']).name)
                            mid_level_env = env.mid_level_env
                            final_metrics['mid_level_modelpath'] = mid_level_model_name
                            final_metrics['position_goals'] = mid_level_env.position_goals
                            final_metrics['velocity_goals'] = mid_level_env.velocity_goals
                            final_metrics['goal_dist'] = mid_level_env.goal_dist
                            final_metrics['distance_reward'] = mid_level_env.distance_reward
                            final_metrics['goal_importance'] = mid_level_env.goal_importance_framework
                            final_metrics['low_level_goal_repeat'] = mid_level_env.action_repeat
                            final_metrics['mid_level_goal_repeat'] = env.action_repeat
                            final_metrics['no_root_goals'] = mid_level_env.no_root_goals

                        total_steps = list(map(int, list(training_metrics.keys())[1:]))
                        ind = jp.argmax(jp.array(total_steps) > steps)
                        
                        if ind == 0:
                            continue
                        
                        final_metrics.update(training_metrics[list(training_metrics.keys())[ind]])
                        final_metrics = {key: f"{value['mean']:.4f} ± {value['std']:.4f}" if isinstance(value, dict) else value for key, value in final_metrics.items()}

                        data.append(final_metrics)

    data = pd.DataFrame(data)
    data.sort_values(by=['model', 'environment', 'model_variant_id'], inplace=True, ascending=True)

    savepath = f"experimental_results.csv"
    data.to_csv(savepath, index=False)

    return data
data = generate_data_tables()
data.model_variant_id = data.model_variant_id.astype(int)
# Out:
# 2023-09-06 16:16:09.467873: E external/xla/xla/stream_executor/cuda/cuda_driver.cc:268] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)

# %%
benchmark_task_data = data[(data.environment == 'gaps') | (data.environment == 'hurdles') | (data.environment == 'maze')].sort_values(by="model_variant_id")
benchmark_task_data.head(60)
# Out:
#                       date model environment  model_variant_id  \
# 52   08/23 16:04:50.987238  flat        gaps                 0
# 16   09/01 19:25:50.394703  hma2     hurdles                 0
# 69   09/01 17:31:56.512055  hma3        gaps                 0
# 56   09/01 17:32:08.839150  hma2        gaps                 0
# 28   09/01 18:55:25.429782  hma3     hurdles                 0
# 92   08/21 14:58:42.077404  flat        maze                 0
# 96   08/31 21:23:22.167049  hma2        maze                 0
# 12   08/23 16:30:26.552281  flat     hurdles                 0
# 110  09/01 19:03:27.770658  hma3        maze                 0
# 97   08/31 21:43:15.846383  hma2        maze                 1
# 13   08/23 16:45:29.246827  flat     hurdles                 1
# 93   08/21 14:58:42.079061  flat        maze                 1
# 57   09/01 17:32:08.840888  hma2        gaps                 1
# 70   09/01 17:31:56.653525  hma3        gaps                 1
# 17   09/01 19:28:25.237511  hma2     hurdles                 1
# 53   08/23 16:07:53.808451  flat        gaps                 1
# 108  09/01 19:03:36.177145  hma3        maze                 1
# 30   09/01 18:55:32.417019  hma3     hurdles                 1
# 109  09/01 19:08:53.269488  hma3        maze                 2
# 98   08/31 23:07:38.069035  hma2        maze                 2
# 18   09/01 19:38:33.530714  hma2     hurdles                 2
# 31   09/01 18:55:34.392534  hma3     hurdles                 2
# 68   09/01 17:31:55.924243  hma3        gaps                 2
# 54   08/23 16:08:57.927963  flat        gaps                 2
# 14   08/23 16:48:26.856003  flat     hurdles                 2
# 94   08/21 14:58:42.082834  flat        maze                 2
# 58   09/01 17:32:02.338932  hma2        gaps                 2
# 55   08/23 16:14:20.977163  flat        gaps                 3
# 15   08/23 16:53:55.903832  flat     hurdles                 3
# 95   08/21 14:58:42.084903  flat        maze                 3
# 71   09/01 17:31:56.535625  hma3        gaps                 3
# 99   08/31 22:09:08.264767  hma2        maze                 3
# 29   09/01 19:02:08.805293  hma3     hurdles                 3
# 19   09/01 19:45:09.448949  hma2     hurdles                 3
# 111  09/01 19:09:57.546086  hma3        maze                 3
# 59   09/01 17:32:02.339592  hma2        gaps                 3
# 73   09/01 17:31:56.466388  hma3        gaps                 4
# 20   09/01 19:45:17.143503  hma2     hurdles                 4
# 112  09/01 19:12:12.109664  hma3        maze                 4
# 60   09/01 17:32:04.574638  hma2        gaps                 4
# 32   09/01 19:03:19.252594  hma3     hurdles                 4
# 100  08/31 22:21:20.154160  hma2        maze                 4
# 33   09/01 19:03:19.810919  hma3     hurdles                 5
# 72   09/01 17:31:56.683909  hma3        gaps                 5
# 61   09/01 17:31:47.624326  hma2        gaps                 5
# 21   09/01 19:48:12.480243  hma2     hurdles                 5
# 113  09/01 19:19:36.973016  hma3        maze                 5
# 101  08/31 22:29:45.614199  hma2        maze                 5
# 102  08/31 23:07:30.914537  hma2        maze                 6
# 75   09/01 18:03:52.730350  hma3        gaps                 6
# 114  09/01 19:21:26.767160  hma3        maze                 6
# 22   09/01 19:48:14.790949  hma2     hurdles                 6
# 63   09/01 17:31:47.627706  hma2        gaps                 6
# 34   09/01 19:03:23.308175  hma3     hurdles                 6
# 115  09/01 19:24:54.719801  hma3        maze                 7
# 74   09/01 18:04:07.511675  hma3        gaps                 7
# 23   09/01 19:48:19.809880  hma2     hurdles                 7
# 35   09/01 21:51:21.864449  hma3     hurdles                 7
# 103  09/01 00:11:57.183483  hma2        maze                 7
# 62   09/01 17:31:47.622642  hma2        gaps                 7
#
#                                              modelpath position_goals  \
# 52   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 16   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 69   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 56   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 28   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 92   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 96   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 12   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 110  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 97   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 13   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 93   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 57   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 70   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 17   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 53   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 108  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 30   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 109  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 98   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 18   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 31   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 68   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 54   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 14   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 94   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 58   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 55   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 15   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 95   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...            NaN
# 71   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 99   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 29   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 19   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 111  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 59   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 73   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 20   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 112  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 60   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 32   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 100  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 33   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 72   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 61   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 21   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 113  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 101  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 102  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 75   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 114  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 22   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 63   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 34   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 115  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 74   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 23   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 35   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 103  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 62   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
#
#     velocity_goals goal_dist distance_reward goal_importance  eval/walltime  \
# 52             NaN       NaN             NaN             NaN     637.383656
# 16            None  relative        relative            None     505.791670
# 69           False  relative        relative            None     751.182489
# 56            None  relative        relative            None     528.728526
# 28           False  relative        relative            None     582.337234
# 92             NaN       NaN             NaN             NaN     406.010040
# 96            None  relative        relative            None     558.515859
# 12             NaN       NaN             NaN             NaN     488.048548
# 110          False  relative        relative            None     657.626256
# 97            None  relative        relative            None     420.275768
# 13             NaN       NaN             NaN             NaN     530.456856
# 93             NaN       NaN             NaN             NaN     406.054462
# 57            None  relative        relative            None     383.791551
# 70           False  relative        relative            None     573.064839
# 17            None  relative        relative            None     325.713878
# 53             NaN       NaN             NaN             NaN     532.839650
# 108          False  relative        relative            None     484.183834
# 30           False  relative        relative            None     437.372858
# 109          False  relative        relative            None     525.613597
# 98            None  relative        relative            None     197.690996
# 18            None  relative        relative            None     517.014422
# 31           False  relative        relative            None     583.968189
# 68           False  relative        relative            None     752.448295
# 54             NaN       NaN             NaN             NaN     701.500392
# 14             NaN       NaN             NaN             NaN     484.473635
# 94             NaN       NaN             NaN             NaN     405.088114
# 58            None  relative        relative            None     507.868885
# 55             NaN       NaN             NaN             NaN     636.191034
# 15             NaN       NaN             NaN             NaN     392.245999
# 95             NaN       NaN             NaN             NaN     404.082426
# 71           False  relative        relative            None     572.938010
# 99            None  relative        relative            None     122.656241
# 29           False  relative        relative            None     399.939934
# 19            None  relative        relative            None     425.247436
# 111          False  relative        relative            None     426.372229
# 59            None  relative        relative            None     387.182284
# 73           False  relative        relative      continuous     760.871933
# 20            None  relative        relative      continuous     581.535127
# 112          False  relative        relative      continuous     562.090425
# 60            None  relative        relative      continuous     559.365534
# 32           False  relative        relative      continuous     588.637349
# 100           None  relative        relative      continuous     556.612096
# 33           False  relative        relative      continuous     436.194092
# 72           False  relative        relative      continuous     567.311002
# 61            None  relative        relative      continuous     566.893131
# 21            None  relative        relative      continuous     427.042957
# 113          False  relative        relative      continuous     358.863194
# 101           None  relative        relative      continuous     416.749981
# 102           None  relative        relative      continuous     226.304377
# 75           False  relative        relative      continuous     577.284905
# 114          False  relative        relative      continuous     575.280756
# 22            None  relative        relative      continuous     583.120346
# 63            None  relative        relative      continuous     753.393311
# 34           False  relative        relative      continuous     588.042403
# 115          False  relative        relative      continuous     353.096975
# 74           False  relative        relative      continuous     441.281208
# 23            None  relative        relative      continuous     394.159479
# 35           False  relative        relative      continuous     411.579313
# 103           None  relative        relative      continuous     104.797220
# 62            None  relative        relative      continuous     567.297867
#
#       training/sps  training/walltime training/entropy_loss  \
# 52    18720.295301        2645.327901           0.047543835
# 16    70171.901776         729.478814            -0.3541124
# 69    12947.059781        3875.615715            -0.1242146
# 56    16202.814889        3101.010910           -0.33758193
# 28    23203.857902        2169.369689           -0.13767004
# 92    17196.503846        2923.038955            0.00425608
# 96    25663.955638        1972.099095           -0.33664376
# 12   107555.444835         484.782585           0.010198812
# 110   17209.901484        2924.036806           -0.14807151
# 97    30959.568746        1620.311514           -0.23517275
# 13    21769.313901        2307.236414          0.0051046032
# 93    17187.734990        2910.879368        -3.3112465e-05
# 57    17776.683329        2791.301084           -0.30050564
# 70    14350.739201        3447.762644           -0.07066451
# 17    32546.390355        1539.240744           -0.22637348
# 53    74758.721771         689.897631          0.0070653376
# 108   19824.261813        2504.579687           -0.16795224
# 30    26545.199130        1879.290672           -0.12121169
# 109   21935.286418        2304.752150           -0.15235516
# 98    39861.081412        1235.457426           -0.30032516
# 18    69912.996455         734.392388           -0.36599198
# 31    23295.243166        2168.511502           -0.19460517
# 68    12922.503577        3874.100023           -0.19534743
# 54    12942.585576        3864.850369          -0.043072186
# 14   108873.429058         478.215521          -0.028926719
# 94    17215.193416        2912.812765          -0.012128435
# 58    16305.930181        3075.145188           -0.38509563
# 55    18893.891101        2607.309205          -0.030772867
# 15    55065.724531         936.642499         -0.0147297755
# 95    17272.798893        2914.054491          -0.038860492
# 71    14368.414188        3443.354452           -0.16654822
# 99    31731.097594        1461.095524           -0.32912332
# 29    79583.441825         640.162689           -0.14860326
# 19    26693.629796        1864.197572            -0.3289144
# 111   61202.002350         827.883871           -0.17132145
# 59    17545.596170        2829.528116            -0.3578037
# 73    12938.313297        3874.911922           -0.13189279
# 20    23154.908719        2174.689992           -0.40300065
# 112   21844.590563        2317.540114           -0.18678577
# 60    42039.834705        1201.423940           -0.38428724
# 32    23203.815985        2168.812332            -0.1738683
# 100   25573.086286        1985.966097           -0.36538514
# 33    26474.023456        1878.078434           -0.14236711
# 72    14315.465473        3450.314230          -0.087938875
# 61    14296.071383        3452.291663           -0.27821726
# 21    26605.796205        1872.408910           -0.35449317
# 113   25135.546528        1992.692669            -0.1700351
# 101   30898.200874        1621.705974            -0.3748517
# 102   32114.203358        1587.395527            -0.3809443
# 75    16292.085687        3110.351851           -0.22877765
# 114   21992.987573        2309.738972           -0.18819332
# 22    23059.327063        2177.805993            -0.4335707
# 63    12876.091583        3891.298978           -0.44319686
# 34    23239.291782        2168.604051           -0.23195907
# 115   24757.475136        2015.214048           -0.19331679
# 74    47665.286439        1056.250918            -0.1984981
# 23    79959.706070         635.551724            -0.4350251
# 35    78947.202021         643.243724           -0.18803568
# 103   40921.148032        1134.475711            -0.3914144
# 62    14337.000813        3454.848166            -0.4372347
#
#     training/policy_loss training/total_loss training/v_loss  \
# 52         -0.0042487886            3019.441       3019.3975
# 16          -0.007018502            900.3866       900.74774
# 69         -0.0054017645            905.9264       906.05597
# 56         -0.0068267416           5254.4106        5254.755
# 28         -0.0072198976            438.7552       438.90002
# 92          0.0068956353            2018.471       2018.4598
# 96           -0.00396576           235.87933       236.21994
# 12          -0.004067738           929.78186       929.77576
# 110        -0.0038786086            270.4484       270.60037
# 97         -0.0032236055           5821.5312       5821.7695
# 13          -0.003042928           1301.0298       1301.0277
# 93         -0.0020681524           519.14954        519.1516
# 57          -0.008561479           6697.4116       6697.7207
# 70          -0.003027088            4207.169        4207.243
# 17            0.07765958           1512.5468       1512.6956
# 53           -0.00567444            8268.706        8268.705
# 108        -0.0061179437             7668.24        7668.414
# 30         -0.0061968886            827.1645       827.29193
# 109        -0.0057540582         0.021603487      0.17971271
# 98         -0.0096857445           13914.288       13914.598
# 18         -0.0061523225          -0.2562486      0.11589567
# 31          -0.004443445         -0.19238634     0.006662271
# 68         -0.0011962943         -0.19639334   0.00015037341
# 54         -0.0009570353         -0.04279979    0.0012294321
# 14          -0.003067119          0.02164093      0.05363477
# 94         -0.0038910378          0.30222932       0.3182488
# 58         -0.0009230969          -0.3858124   0.00020631256
# 55         -0.0030697533        -0.033318225   0.00052439334
# 15          -0.006284902          0.22670043      0.24771509
# 95         -0.0036972775        -0.020864045     0.021693729
# 71          -0.007769903        -0.040384606      0.13393353
# 99          -0.013841389            35484.71        35485.05
# 29         -0.0068553444         -0.02232109      0.13313752
# 19         -0.0049100975         -0.13083208      0.20299242
# 111        -0.0075825313           1.4488326       1.6277366
# 59         -0.0022442997         -0.31820667      0.04184134
# 73         -0.0063071586            2612.212         2612.35
# 20          -0.007556474            653.6627       654.07336
# 112         -0.005077442            306.4088       306.60068
# 60         -0.0037204768            6053.394        6053.782
# 32          -0.009165352           412.32324        412.5063
# 100        -0.0058110654           328.76886       329.14008
# 33         -0.0065073953            884.5188        884.6677
# 72          -0.005462247            5367.325        5367.419
# 61         -0.0055806516           4058.3677       4058.6514
# 21          -0.003560911          1017.03345       1017.3915
# 113         -0.006442667           7618.5664        7618.743
# 101         -0.009211972           2338.2544       2338.6387
# 102         -0.012354742              4702.2       4702.5938
# 75          -0.002618134         -0.23137018     2.56179e-05
# 114        -0.0058442196        -0.002338116      0.19169942
# 22         -0.0055382536         -0.38402256      0.05508641
# 63            0.00943915         -0.43329662   0.00046106824
# 34         -0.0006878745         -0.22887486    0.0037720734
# 115         -0.007231936            2.310302       2.5108507
# 74          -0.006302714         -0.17874785     0.026052948
# 23         -0.0051370794         -0.29916382       0.1409983
# 35         -0.0072370423          -0.0912212      0.10405152
# 103        -0.0074763624            8386.834        8387.232
# 62          0.0016550065         -0.39389542     0.041684233
#
#      eval/episode_cumulative_final_goal_dist  eval/episode_cumulative_return  \
# 52                                       NaN                             NaN
# 16                                       NaN                             NaN
# 69                                       NaN                             NaN
# 56                                       NaN                             NaN
# 28                                       NaN                             NaN
# 92                                       NaN                             NaN
# 96                                       NaN                             NaN
# 12                                       NaN                             NaN
# 110                                      NaN                             NaN
# 97                                       NaN                             NaN
# 13                                       NaN                             NaN
# 93                                       NaN                             NaN
# 57                                       NaN                             NaN
# 70                                       NaN                             NaN
# 17                                       NaN                             NaN
# 53                                       NaN                             NaN
# 108                                      NaN                             NaN
# 30                                       NaN                             NaN
# 109                                      NaN                             NaN
# 98                                       NaN                             NaN
# 18                                       NaN                             NaN
# 31                                       NaN                             NaN
# 68                                       NaN                             NaN
# 54                                       NaN                             NaN
# 14                                       NaN                             NaN
# 94                                       NaN                             NaN
# 58                                       NaN                             NaN
# 55                                       NaN                             NaN
# 15                                       NaN                             NaN
# 95                                       NaN                             NaN
# 71                                       NaN                             NaN
# 99                                       NaN                             NaN
# 29                                       NaN                             NaN
# 19                                       NaN                             NaN
# 111                                      NaN                             NaN
# 59                                       NaN                             NaN
# 73                                       NaN                             NaN
# 20                                       NaN                             NaN
# 112                                      NaN                             NaN
# 60                                       NaN                             NaN
# 32                                       NaN                             NaN
# 100                                      NaN                             NaN
# 33                                       NaN                             NaN
# 72                                       NaN                             NaN
# 61                                       NaN                             NaN
# 21                                       NaN                             NaN
# 113                                      NaN                             NaN
# 101                                      NaN                             NaN
# 102                                      NaN                             NaN
# 75                                       NaN                             NaN
# 114                                      NaN                             NaN
# 22                                       NaN                             NaN
# 63                                       NaN                             NaN
# 34                                       NaN                             NaN
# 115                                      NaN                             NaN
# 74                                       NaN                             NaN
# 23                                       NaN                             NaN
# 35                                       NaN                             NaN
# 103                                      NaN                             NaN
# 62                                       NaN                             NaN
#
#     eval/episode_goal_dist eval/episode_goals_reached  \
# 52                     NaN                        NaN
# 16                     NaN                        NaN
# 69                     NaN                        NaN
# 56                     NaN                        NaN
# 28                     NaN                        NaN
# 92                     NaN                        NaN
# 96                     NaN                        NaN
# 12                     NaN                        NaN
# 110                    NaN                        NaN
# 97                     NaN                        NaN
# 13                     NaN                        NaN
# 93                     NaN                        NaN
# 57                     NaN                        NaN
# 70                     NaN                        NaN
# 17                     NaN                        NaN
# 53                     NaN                        NaN
# 108                    NaN                        NaN
# 30                     NaN                        NaN
# 109                    NaN                        NaN
# 98                     NaN                        NaN
# 18                     NaN                        NaN
# 31                     NaN                        NaN
# 68                     NaN                        NaN
# 54                     NaN                        NaN
# 14                     NaN                        NaN
# 94                     NaN                        NaN
# 58                     NaN                        NaN
# 55                     NaN                        NaN
# 15                     NaN                        NaN
# 95                     NaN                        NaN
# 71                     NaN                        NaN
# 99                     NaN                        NaN
# 29                     NaN                        NaN
# 19                     NaN                        NaN
# 111                    NaN                        NaN
# 59                     NaN                        NaN
# 73                     NaN                        NaN
# 20                     NaN                        NaN
# 112                    NaN                        NaN
# 60                     NaN                        NaN
# 32                     NaN                        NaN
# 100                    NaN                        NaN
# 33                     NaN                        NaN
# 72                     NaN                        NaN
# 61                     NaN                        NaN
# 21                     NaN                        NaN
# 113                    NaN                        NaN
# 101                    NaN                        NaN
# 102                    NaN                        NaN
# 75                     NaN                        NaN
# 114                    NaN                        NaN
# 22                     NaN                        NaN
# 63                     NaN                        NaN
# 34                     NaN                        NaN
# 115                    NaN                        NaN
# 74                     NaN                        NaN
# 23                     NaN                        NaN
# 35                     NaN                        NaN
# 103                    NaN                        NaN
# 62                     NaN                        NaN
#
#     eval/episode_is_unhealthy   eval/episode_reward  eval/episode_weight  \
# 52            0.9766 ± 0.1513   580.4637 ± 160.2983                  NaN
# 16            0.5312 ± 0.4990   716.3678 ± 223.3758                  NaN
# 69            1.0000 ± 0.0000    200.3405 ± 50.7137                  NaN
# 56            0.9766 ± 0.1513   514.2386 ± 188.6013                  NaN
# 28            0.9609 ± 0.1937   307.1085 ± 125.3958                  NaN
# 92            0.0000 ± 0.0000   1242.9519 ± 29.0910                  NaN
# 96            0.0000 ± 0.0000   1236.5723 ± 28.3176                  NaN
# 12            0.5547 ± 0.4970   703.4703 ± 248.1740                  NaN
# 110           0.0000 ± 0.0000   1242.1660 ± 28.8175                  NaN
# 97            0.2422 ± 0.4284  1102.4451 ± 217.5640                  NaN
# 13            0.2422 ± 0.4284   815.7398 ± 190.7082                  NaN
# 93            0.0312 ± 0.1740   1132.1674 ± 96.5140                  NaN
# 57            1.0000 ± 0.0000     78.4016 ± 41.2806                  NaN
# 70            1.0000 ± 0.0000     66.2148 ± 33.7953                  NaN
# 17            0.7656 ± 0.4236    168.1974 ± 89.0307                  NaN
# 53            0.9375 ± 0.2421   556.6655 ± 225.0064                  NaN
# 108           0.2266 ± 0.4186  1051.6949 ± 311.0792                  NaN
# 30            0.9297 ± 0.2557    104.6161 ± 55.7193                  NaN
# 109           0.0234 ± 0.1513      21.6094 ± 2.2123                  NaN
# 98            0.1562 ± 0.3631   794.4333 ± 209.0697                  NaN
# 18            0.4609 ± 0.4985       6.3750 ± 2.9501                  NaN
# 31            0.1016 ± 0.3021       1.0859 ± 0.5004                  NaN
# 68            0.0078 ± 0.0880      -0.0078 ± 0.0880                  NaN
# 54            0.0469 ± 0.2114      -0.0469 ± 0.2114                  NaN
# 14            0.3594 ± 0.4798       5.1406 ± 1.6805                  NaN
# 94            0.0234 ± 0.1513      21.6797 ± 1.8197                  NaN
# 58            0.0078 ± 0.0880      -0.0078 ± 0.0880                  NaN
# 55            0.0156 ± 0.1240      -0.0156 ± 0.1240                  NaN
# 15            0.3750 ± 0.4841       6.6562 ± 2.1882                  NaN
# 95            0.0156 ± 0.1240       9.2734 ± 2.9067                  NaN
# 71            0.5703 ± 0.4950      -0.4453 ± 0.5421                  NaN
# 99            0.1797 ± 0.3839   507.9654 ± 113.8705                  NaN
# 29            0.3359 ± 0.4723       0.7422 ± 0.7526                  NaN
# 19            0.4297 ± 0.4950       1.2422 ± 0.9581                  NaN
# 111           0.2188 ± 0.4134      18.0156 ± 5.3648                  NaN
# 59            0.1875 ± 0.3903      -0.1875 ± 0.3903                  NaN
# 73            1.0000 ± 0.0000    313.8403 ± 98.7516                  NaN
# 20            0.3047 ± 0.4603   797.5676 ± 219.9345                  NaN
# 112           0.0078 ± 0.0880   1243.9814 ± 98.6240                  NaN
# 60            0.8438 ± 0.3631   699.1407 ± 223.0759                  NaN
# 32            0.6641 ± 0.4723   491.1219 ± 197.3596                  NaN
# 100           0.0469 ± 0.2114  1049.9604 ± 137.2335                  NaN
# 33            0.7500 ± 0.4330    136.0077 ± 55.1825                  NaN
# 72            1.0000 ± 0.0000     72.3811 ± 37.7110                  NaN
# 61            1.0000 ± 0.0000     68.8972 ± 35.1785                  NaN
# 21            0.6719 ± 0.4695    141.4592 ± 69.8416                  NaN
# 113           0.1172 ± 0.3216  1138.8872 ± 207.1225                  NaN
# 101           0.1250 ± 0.3307    648.8408 ± 98.0409                  NaN
# 102           0.2031 ± 0.4023   492.5511 ± 123.2035                  NaN
# 75            0.0234 ± 0.1513      -0.0234 ± 0.1513                  NaN
# 114           0.0078 ± 0.0880      21.7734 ± 1.9252                  NaN
# 22            0.2734 ± 0.4457       4.9531 ± 1.9359                  NaN
# 63            0.0078 ± 0.0880      -0.0078 ± 0.0880                  NaN
# 34            0.0547 ± 0.2274       0.9453 ± 0.2274                  NaN
# 115           0.1016 ± 0.3021      19.9922 ± 4.6309                  NaN
# 74            0.1250 ± 0.3307      -0.1250 ± 0.4146                  NaN
# 23            0.3203 ± 0.4666       0.9922 ± 0.7654                  NaN
# 35            0.2344 ± 0.4236       0.9844 ± 0.7393                  NaN
# 103           0.1641 ± 0.3703    360.4230 ± 70.9968                  NaN
# 62            0.2500 ± 0.4330      -0.2422 ± 0.4284                  NaN
#
#     eval/avg_episode_length  eval/epoch_eval_time      eval/sps state_below  \
# 52       196.6641 ± 65.8971             15.804931  12148.107139         NaN
# 16      789.4375 ± 332.0717             12.550131  15298.645280        True
# 69        98.2578 ± 29.8329             18.741768  10244.497547         NaN
# 56       178.3438 ± 55.9805             12.763921  15042.400124        True
# 28      570.1953 ± 354.8539             14.408819  13325.172186         NaN
# 92       501.9375 ± 49.8905              9.964273  12845.893944         NaN
# 96       613.5938 ± 31.9598             13.969202  13744.521658        True
# 12      570.3672 ± 257.3593             12.124888  15835.197269         NaN
# 110      591.2891 ± 29.4823             16.290392  11786.088273         NaN
# 97     1300.7422 ± 298.7409             12.757638  15049.808398        True
# 13      461.1875 ± 130.5608             13.196745  14549.041771         NaN
# 93      848.9766 ± 104.0064              9.953087  12860.331556         NaN
# 57        70.5078 ± 26.1668             11.783311  16294.231554        True
# 70        68.5547 ± 26.2586             17.846302  10758.531499         NaN
# 17      878.8672 ± 495.8174              9.775467  19641.005070        True
# 53       157.8359 ± 62.1774             13.322667  14411.528731         NaN
# 108    1102.5000 ± 369.0618             14.979496  12817.520694         NaN
# 30      640.3125 ± 425.4817             13.490178  14232.576847         NaN
# 109     563.9453 ± 141.7215             12.700811  15117.144706         NaN
# 98     1368.8281 ± 353.5591             11.461427  16751.840800        True
# 18     1046.4844 ± 456.9938             12.803913  14995.415997        True
# 31     1444.7266 ± 206.5461             14.471096  13267.827087         NaN
# 68      1493.0000 ± 78.8860             18.806456  10209.260265         NaN
# 54     1464.5547 ± 175.5728             17.535783  10949.040715         NaN
# 14     1125.3203 ± 543.5779             12.036588  15951.364036         NaN
# 94       567.8125 ± 78.0951              9.983651  12820.960782         NaN
# 58     1490.0547 ± 112.0780             12.033967  15954.839108        True
# 55      1491.5547 ± 68.4918             15.520979  12370.353568         NaN
# 15     1273.8984 ± 365.2182              9.455919  20304.742399         NaN
# 95       991.4688 ± 83.7308              9.972862  12834.831158         NaN
# 71     1035.0391 ± 501.6245             17.734300  10826.477566         NaN
# 99     1400.4688 ± 275.9921             13.079969  14678.933684        True
# 29     1274.1797 ± 417.0679             12.283018  15631.337671         NaN
# 19     1226.1719 ± 408.0094             13.097452  14659.339931        True
# 111    1321.5625 ± 320.5109             13.189785  14556.719720         NaN
# 59     1339.6875 ± 383.8501             12.095995  15873.021875        True
# 73       137.5859 ± 38.0548             18.989399  10110.904407         NaN
# 20      842.5234 ± 277.0578             14.505269  13236.569804        True
# 112      565.9141 ± 51.5372             13.661618  14053.971746         NaN
# 60       221.4297 ± 64.0241             13.814437  13898.503516        True
# 32      983.0547 ± 488.1165             14.608621  13142.924625         NaN
# 100    1402.5000 ± 223.3468             13.711814  14002.523251        True
# 33      929.9609 ± 472.3593             13.361126  14370.046415         NaN
# 72        70.0781 ± 26.4795             17.610069  10902.853339         NaN
# 61        75.3906 ± 27.1541             17.692559  10852.019472        True
# 21      957.6562 ± 499.2866             13.234063  14508.015746        True
# 113    1172.1094 ± 258.6417             10.696032  17950.582368         NaN
# 101    1388.7109 ± 318.9425             13.199398  14546.118417        True
# 102    1321.2500 ± 394.9189             12.901192  14882.346088        True
# 75     1485.3594 ± 104.8116             14.069392  13646.645176         NaN
# 114     556.2188 ± 123.1082             13.998270  13715.980350         NaN
# 22     1262.1250 ± 438.7133             14.469208  13269.557922        True
# 63      1495.7500 ± 47.8951             18.829970  10196.511005        True
# 34     1459.0078 ± 199.0960             14.659434  13097.368234         NaN
# 115    1266.2109 ± 278.5711             10.517437  18255.399015         NaN
# 74     1409.5312 ± 273.2476             13.602939  14114.596719         NaN
# 23     1292.5781 ± 385.5120             12.161274  15787.819346        True
# 35     1358.6328 ± 326.5125             12.637610  15192.745860         NaN
# 103    1363.5938 ± 332.4195             11.428096  16800.699177        True
# 62     1294.1797 ± 392.4347             17.622874  10894.931347        True
#
#      low_level_modelpath  action_repeat no_root_goals  low_level_goal_repeat  \
# 52                   NaN            NaN           NaN                    NaN
# 16                   0.0            1.0           NaN                    1.0
# 69                   NaN            1.0         False                    1.0
# 56                   0.0            1.0           NaN                    1.0
# 28                   NaN            1.0         False                    1.0
# 92                   NaN            NaN           NaN                    NaN
# 96                   0.0            1.0           NaN                    1.0
# 12                   NaN            NaN           NaN                    NaN
# 110                  NaN            1.0         False                    1.0
# 97                   0.0            5.0           NaN                    5.0
# 13                   NaN            NaN           NaN                    NaN
# 93                   NaN            NaN           NaN                    NaN
# 57                   0.0            5.0           NaN                    5.0
# 70                   NaN            5.0         False                    1.0
# 17                   0.0            5.0           NaN                    5.0
# 53                   NaN            NaN           NaN                    NaN
# 108                  NaN            5.0         False                    1.0
# 30                   NaN            5.0         False                    1.0
# 109                  NaN            1.0         False                    1.0
# 98                   0.0            1.0           NaN                   10.0
# 18                   0.0            1.0           NaN                    1.0
# 31                   NaN            1.0         False                    1.0
# 68                   NaN            1.0         False                    1.0
# 54                   NaN            NaN           NaN                    NaN
# 14                   NaN            NaN           NaN                    NaN
# 94                   NaN            NaN           NaN                    NaN
# 58                   0.0            1.0           NaN                    1.0
# 55                   NaN            NaN           NaN                    NaN
# 15                   NaN            NaN           NaN                    NaN
# 95                   NaN            NaN           NaN                    NaN
# 71                   NaN            5.0         False                    1.0
# 99                   0.0            5.0           NaN                   20.0
# 29                   NaN            5.0         False                    1.0
# 19                   0.0            5.0           NaN                    5.0
# 111                  NaN            5.0         False                    1.0
# 59                   0.0            5.0           NaN                    5.0
# 73                   NaN            1.0         False                    1.0
# 20                   1.0            1.0           NaN                    1.0
# 112                  NaN            1.0         False                    1.0
# 60                   1.0            1.0           NaN                    1.0
# 32                   NaN            1.0         False                    1.0
# 100                  1.0            1.0           NaN                    1.0
# 33                   NaN            5.0         False                    1.0
# 72                   NaN            5.0         False                    1.0
# 61                   1.0            5.0           NaN                    5.0
# 21                   1.0            5.0           NaN                    5.0
# 113                  NaN            5.0         False                    1.0
# 101                  1.0            5.0           NaN                    5.0
# 102                  1.0            1.0           NaN                   10.0
# 75                   NaN            1.0         False                    1.0
# 114                  NaN            1.0         False                    1.0
# 22                   1.0            1.0           NaN                    1.0
# 63                   1.0            1.0           NaN                    1.0
# 34                   NaN            1.0         False                    1.0
# 115                  NaN            5.0         False                    1.0
# 74                   NaN            5.0         False                    1.0
# 23                   1.0            5.0           NaN                    5.0
# 35                   NaN            5.0         False                    1.0
# 103                  1.0            5.0           NaN                   20.0
# 62                   1.0            5.0           NaN                    5.0
#
#     reward_type task_information eval/episode_obstacles_complete  \
# 52        dense             True                11.9375 ± 3.3184
# 16        dense             True                 7.6797 ± 2.5185
# 69        dense             True                 3.8906 ± 1.0985
# 56        dense             True                10.5000 ± 3.9151
# 28        dense             True                 3.2734 ± 1.3504
# 92        dense             True                             NaN
# 96        dense             True                             NaN
# 12        dense             True                 7.5625 ± 2.7436
# 110       dense             True                             NaN
# 97        dense             True                             NaN
# 13        dense            False                 8.8984 ± 2.1825
# 93        dense            False                             NaN
# 57        dense             True                 1.2266 ± 0.9537
# 70        dense             True                 0.9688 ± 0.8655
# 17        dense             True                 1.8672 ± 0.9951
# 53        dense            False                11.4688 ± 4.7069
# 108       dense             True                             NaN
# 30        dense             True                 1.1406 ± 0.6463
# 109      sparse             True                             NaN
# 98       sparse             True                             NaN
# 18       sparse             True                 7.1406 ± 2.8525
# 31       sparse             True                 1.1875 ± 0.3903
# 68       sparse             True                 0.0000 ± 0.0000
# 54       sparse             True                 0.0000 ± 0.0000
# 14       sparse             True                 5.5000 ± 1.3521
# 94       sparse             True                             NaN
# 58       sparse             True                 0.0000 ± 0.0000
# 55       sparse            False                 0.0000 ± 0.0000
# 15       sparse            False                 7.0547 ± 1.8804
# 95       sparse            False                             NaN
# 71       sparse             True                 0.1641 ± 0.3909
# 99       sparse             True                             NaN
# 29       sparse             True                 1.0781 ± 0.4439
# 19       sparse             True                 1.6719 ± 0.6859
# 111      sparse             True                             NaN
# 59       sparse             True                 0.0000 ± 0.0000
# 73        dense             True                 6.3516 ± 2.1382
# 20        dense             True                 8.6719 ± 2.4657
# 112       dense             True                             NaN
# 60        dense             True                14.2734 ± 4.7248
# 32        dense             True                 5.1562 ± 1.9342
# 100       dense             True                             NaN
# 33        dense             True                 1.4609 ± 0.6362
# 72        dense             True                 1.1797 ± 0.9137
# 61        dense             True                 1.0234 ± 0.8702
# 21        dense             True                 1.6016 ± 0.7740
# 113       dense             True                             NaN
# 101       dense             True                             NaN
# 102      sparse             True                             NaN
# 75       sparse             True                 0.0000 ± 0.0000
# 114      sparse             True                             NaN
# 22       sparse             True                 5.2266 ± 1.6067
# 63       sparse             True                 0.0000 ± 0.0000
# 34       sparse             True                 1.0000 ± 0.0000
# 115      sparse             True                             NaN
# 74       sparse             True                 0.0156 ± 0.1761
# 23       sparse             True                 1.3203 ± 0.5581
# 35       sparse             True                 1.2344 ± 0.5075
# 103      sparse             True                             NaN
# 62       sparse             True                 0.0078 ± 0.0880
#
#     eval/episode_task_complete reward_movement  state  mid_level_modelpath  \
# 52             0.0312 ± 0.1740             NaN    NaN                  NaN
# 16             0.4453 ± 0.4970        velocity    NaN                  NaN
# 69             0.0000 ± 0.0000        velocity  below                  0.0
# 56             0.0234 ± 0.1513        velocity    NaN                  NaN
# 28             0.0000 ± 0.0000        velocity  below                  0.0
# 92             0.9922 ± 0.0880             NaN    NaN                  NaN
# 96             1.0000 ± 0.0000        velocity    NaN                  NaN
# 12             0.4453 ± 0.4970             NaN    NaN                  NaN
# 110            1.0000 ± 0.0000        velocity  below                  0.0
# 97             0.3828 ± 0.4861        velocity    NaN                  NaN
# 13             0.7578 ± 0.4284             NaN    NaN                  NaN
# 93             0.7578 ± 0.4284             NaN    NaN                  NaN
# 57             0.0000 ± 0.0000        velocity    NaN                  NaN
# 70             0.0000 ± 0.0000        velocity  below                  0.0
# 17             0.0000 ± 0.0000        velocity    NaN                  NaN
# 53             0.0625 ± 0.2421             NaN    NaN                  NaN
# 108            0.6719 ± 0.4695        velocity  below                  0.0
# 30             0.0000 ± 0.0000        velocity  below                  0.0
# 109            0.9609 ± 0.1937        velocity  below                  0.0
# 98             0.0000 ± 0.0000        velocity    NaN                  NaN
# 18             0.3047 ± 0.4603        velocity    NaN                  NaN
# 31             0.0000 ± 0.0000        velocity  below                  0.0
# 68             0.0000 ± 0.0000        velocity  below                  0.0
# 54             0.0000 ± 0.0000             NaN    NaN                  NaN
# 14             0.0000 ± 0.0000             NaN    NaN                  NaN
# 94             0.9609 ± 0.1937             NaN    NaN                  NaN
# 58             0.0000 ± 0.0000        velocity    NaN                  NaN
# 55             0.0000 ± 0.0000             NaN    NaN                  NaN
# 15             0.0234 ± 0.1513             NaN    NaN                  NaN
# 95             0.0000 ± 0.0000             NaN    NaN                  NaN
# 71             0.0000 ± 0.0000        velocity  below                  0.0
# 99             0.0000 ± 0.0000        velocity    NaN                  NaN
# 29             0.0000 ± 0.0000        velocity  below                  0.0
# 19             0.0000 ± 0.0000        velocity    NaN                  NaN
# 111            0.2578 ± 0.4374        velocity  below                  0.0
# 59             0.0000 ± 0.0000        velocity    NaN                  NaN
# 73             0.0000 ± 0.0000        velocity  below                  1.0
# 20             0.6953 ± 0.4603        velocity    NaN                  NaN
# 112            0.9922 ± 0.0880        velocity  below                  1.0
# 60             0.1797 ± 0.3839        velocity    NaN                  NaN
# 32             0.0000 ± 0.0000        velocity  below                  1.0
# 100            0.1953 ± 0.3964        velocity    NaN                  NaN
# 33             0.0000 ± 0.0000        velocity  below                  1.0
# 72             0.0000 ± 0.0000        velocity  below                  1.0
# 61             0.0000 ± 0.0000        velocity    NaN                  NaN
# 21             0.0000 ± 0.0000        velocity    NaN                  NaN
# 113            0.7578 ± 0.4284        velocity  below                  1.0
# 101            0.0000 ± 0.0000        velocity    NaN                  NaN
# 102            0.0000 ± 0.0000        velocity    NaN                  NaN
# 75             0.0000 ± 0.0000        velocity  below                  1.0
# 114            0.9844 ± 0.1240        velocity  below                  1.0
# 22             0.0000 ± 0.0000        velocity    NaN                  NaN
# 63             0.0000 ± 0.0000        velocity    NaN                  NaN
# 34             0.0000 ± 0.0000        velocity  below                  1.0
# 115            0.6875 ± 0.4635        velocity  below                  1.0
# 74             0.0000 ± 0.0000        velocity  below                  1.0
# 23             0.0000 ± 0.0000        velocity    NaN                  NaN
# 35             0.0000 ± 0.0000        velocity  below                  1.0
# 103            0.0000 ± 0.0000        velocity    NaN                  NaN
# 62             0.0000 ± 0.0000        velocity    NaN                  NaN
#
#      mid_level_goal_repeat eval/episode_distance_to_end  \
# 52                     NaN                          NaN
# 16                     NaN                          NaN
# 69                     1.0                          NaN
# 56                     NaN                          NaN
# 28                     1.0                          NaN
# 92                     NaN              0.0078 ± 0.0880
# 96                     NaN              0.0000 ± 0.0000
# 12                     NaN                          NaN
# 110                    1.0              0.0000 ± 0.0000
# 97                     NaN              2.5859 ± 4.1317
# 13                     NaN                          NaN
# 93                     NaN              0.8125 ± 1.8103
# 57                     NaN                          NaN
# 70                     5.0                          NaN
# 17                     NaN                          NaN
# 53                     NaN                          NaN
# 108                    5.0              3.2031 ± 5.9113
# 30                     5.0                          NaN
# 109                    1.0              0.3672 ± 2.1245
# 98                     NaN              8.1406 ± 4.0287
# 18                     NaN                          NaN
# 31                     1.0                          NaN
# 68                     1.0                          NaN
# 54                     NaN                          NaN
# 14                     NaN                          NaN
# 94                     NaN              0.3203 ± 1.8747
# 58                     NaN                          NaN
# 55                     NaN                          NaN
# 15                     NaN                          NaN
# 95                     NaN             12.8516 ± 2.9130
# 71                     5.0                          NaN
# 99                     NaN             13.7109 ± 2.1764
# 29                     5.0                          NaN
# 19                     NaN                          NaN
# 111                    5.0              3.8750 ± 5.1250
# 59                     NaN                          NaN
# 73                     1.0                          NaN
# 20                     NaN                          NaN
# 112                    1.0              0.1562 ± 1.7608
# 60                     NaN                          NaN
# 32                     1.0                          NaN
# 100                    NaN              2.0625 ± 2.8000
# 33                     5.0                          NaN
# 72                     5.0                          NaN
# 61                     NaN                          NaN
# 21                     NaN                          NaN
# 113                    5.0              1.6328 ± 3.9821
# 101                    NaN             10.1562 ± 2.0480
# 102                    NaN             12.9062 ± 2.5200
# 75                     1.0                          NaN
# 114                    1.0              0.2188 ± 1.8453
# 22                     NaN                          NaN
# 63                     NaN                          NaN
# 34                     1.0                          NaN
# 115                    5.0              1.9531 ± 4.4509
# 74                     5.0                          NaN
# 23                     NaN                          NaN
# 35                     5.0                          NaN
# 103                    NaN             16.5703 ± 1.3845
# 62                     NaN                          NaN
#
#     eval/episode_maze_column eval/episode_maze_row
# 52                       NaN                   NaN
# 16                       NaN                   NaN
# 69                       NaN                   NaN
# 56                       NaN                   NaN
# 28                       NaN                   NaN
# 92           1.0000 ± 0.0000       1.0078 ± 0.0880
# 96           1.0000 ± 0.0000       1.0000 ± 0.0000
# 12                       NaN                   NaN
# 110          1.0000 ± 0.0000       1.0000 ± 0.0000
# 97           1.4766 ± 0.8288       2.0156 ± 1.1179
# 13                       NaN                   NaN
# 93           1.1094 ± 0.3121       1.4531 ± 0.9342
# 57                       NaN                   NaN
# 70                       NaN                   NaN
# 17                       NaN                   NaN
# 53                       NaN                   NaN
# 108          1.5703 ± 1.2034       1.6484 ± 1.2028
# 30                       NaN                   NaN
# 109          1.0625 ± 0.3903       1.0859 ± 0.4846
# 98           2.0547 ± 1.1879       4.1797 ± 0.8877
# 18                       NaN                   NaN
# 31                       NaN                   NaN
# 68                       NaN                   NaN
# 54                       NaN                   NaN
# 14                       NaN                   NaN
# 94           1.0547 ± 0.3603       1.0938 ± 0.5220
# 58                       NaN                   NaN
# 55                       NaN                   NaN
# 15                       NaN                   NaN
# 95           3.6484 ± 0.5941       3.7344 ± 1.3549
# 71                       NaN                   NaN
# 99           3.7578 ± 0.5412       3.0625 ± 1.0807
# 29                       NaN                   NaN
# 19                       NaN                   NaN
# 111          1.6875 ± 1.0364       2.2656 ± 1.0932
# 59                       NaN                   NaN
# 73                       NaN                   NaN
# 20                       NaN                   NaN
# 112          1.0312 ± 0.3522       1.0156 ± 0.1761
# 60                       NaN                   NaN
# 32                       NaN                   NaN
# 100          1.7734 ± 0.5033       1.8203 ± 0.4749
# 33                       NaN                   NaN
# 72                       NaN                   NaN
# 61                       NaN                   NaN
# 21                       NaN                   NaN
# 113          1.2812 ± 0.8095       1.4297 ± 0.8899
# 101          3.2188 ± 0.4667       4.1719 ± 0.8848
# 102          3.9766 ± 0.4044       3.8672 ± 0.9872
# 75                       NaN                   NaN
# 114          1.0469 ± 0.3925       1.0312 ± 0.2778
# 22                       NaN                   NaN
# 63                       NaN                   NaN
# 34                       NaN                   NaN
# 115          1.3750 ± 0.9014       1.5469 ± 1.0221
# 74                       NaN                   NaN
# 23                       NaN                   NaN
# 35                       NaN                   NaN
# 103          4.1328 ± 0.5210       1.7656 ± 0.6902
# 62                       NaN                   NaN

# %%
def get_benchmark_data(environment,  reward_type, task_information, sortby='eval/episode_obstacles_complete', ascending=False):
    if sortby == 'eval/episode_obstacles_complete' and environment == 'maze':
        sortby = 'eval/episode_distance_to_end'
        ascending = True
    elif sortby == 'eval/episode_distance_to_end' and environment != 'maze':
        sortby = 'eval/episode_obstacles_complete'
        ascending = False
    df = benchmark_task_data[(benchmark_task_data.environment == environment) & (benchmark_task_data.reward_type == reward_type) & (benchmark_task_data.task_information == task_information)].sort_values(sortby, ascending=ascending)
    return df
a = get_benchmark_data('maze', 'dense', True, 'action_repeat')
a[a.model == 'hma2'].head(50)
# Out:
#                       date model environment  model_variant_id  \
# 97   08/31 21:43:15.846383  hma2        maze                 1
# 101  08/31 22:29:45.614199  hma2        maze                 5
# 105  09/01 22:28:57.436899  hma2        maze                 9
# 96   08/31 21:23:22.167049  hma2        maze                 0
# 100  08/31 22:21:20.154160  hma2        maze                 4
# 104  09/01 22:28:57.437546  hma2        maze                 8
#
#                                              modelpath position_goals  \
# 97   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 101  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 105  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 96   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 100  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 104  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
#
#     velocity_goals goal_dist distance_reward goal_importance  eval/walltime  \
# 97            None  relative        relative            None     420.275768
# 101           None  relative        relative      continuous     416.749981
# 105           None  relative        relative        discrete     350.516713
# 96            None  relative        relative            None     558.515859
# 100           None  relative        relative      continuous     556.612096
# 104           None  relative        relative        discrete     539.923275
#
#      training/sps  training/walltime training/entropy_loss  \
# 97   30959.568746        1620.311514           -0.23517275
# 101  30898.200874        1621.705974            -0.3748517
# 105  24897.569646        2012.292911           -0.32174164
# 96   25663.955638        1972.099095           -0.33664376
# 100  25573.086286        1985.966097           -0.36538514
# 104  21699.864841        2326.992051           -0.39686877
#
#     training/policy_loss training/total_loss training/v_loss  \
# 97         -0.0032236055           5821.5312       5821.7695
# 101         -0.009211972           2338.2544       2338.6387
# 105         0.0031124572            6052.969       6053.2876
# 96           -0.00396576           235.87933       236.21994
# 100        -0.0058110654           328.76886       329.14008
# 104        0.00013092461           347.48654        347.8833
#
#      eval/episode_cumulative_final_goal_dist  eval/episode_cumulative_return  \
# 97                                       NaN                             NaN
# 101                                      NaN                             NaN
# 105                                      NaN                             NaN
# 96                                       NaN                             NaN
# 100                                      NaN                             NaN
# 104                                      NaN                             NaN
#
#     eval/episode_goal_dist eval/episode_goals_reached  \
# 97                     NaN                        NaN
# 101                    NaN                        NaN
# 105                    NaN                        NaN
# 96                     NaN                        NaN
# 100                    NaN                        NaN
# 104                    NaN                        NaN
#
#     eval/episode_is_unhealthy   eval/episode_reward  eval/episode_weight  \
# 97            0.2422 ± 0.4284  1102.4451 ± 217.5640                  NaN
# 101           0.1250 ± 0.3307    648.8408 ± 98.0409                  NaN
# 105           0.1875 ± 0.3903  1130.5405 ± 240.8946                  NaN
# 96            0.0000 ± 0.0000   1236.5723 ± 28.3176                  NaN
# 100           0.0469 ± 0.2114  1049.9604 ± 137.2335                  NaN
# 104           0.0000 ± 0.0000   1232.9629 ± 28.5058                  NaN
#
#     eval/avg_episode_length  eval/epoch_eval_time      eval/sps state_below  \
# 97     1300.7422 ± 298.7409             12.757638  15049.808398        True
# 101    1388.7109 ± 318.9425             13.199398  14546.118417        True
# 105    1221.2891 ± 341.5814             10.403116  18456.008356        True
# 96       613.5938 ± 31.9598             13.969202  13744.521658        True
# 100    1402.5000 ± 223.3468             13.711814  14002.523251        True
# 104      605.8281 ± 35.0237             13.081959  14676.700398        True
#
#      low_level_modelpath  action_repeat no_root_goals  low_level_goal_repeat  \
# 97                   0.0            5.0           NaN                    5.0
# 101                  1.0            5.0           NaN                    5.0
# 105                  2.0            5.0           NaN                    5.0
# 96                   0.0            1.0           NaN                    1.0
# 100                  1.0            1.0           NaN                    1.0
# 104                  2.0            1.0           NaN                    1.0
#
#     reward_type task_information eval/episode_obstacles_complete  \
# 97        dense             True                             NaN
# 101       dense             True                             NaN
# 105       dense             True                             NaN
# 96        dense             True                             NaN
# 100       dense             True                             NaN
# 104       dense             True                             NaN
#
#     eval/episode_task_complete reward_movement state  mid_level_modelpath  \
# 97             0.3828 ± 0.4861        velocity   NaN                  NaN
# 101            0.0000 ± 0.0000        velocity   NaN                  NaN
# 105            0.5938 ± 0.4911        velocity   NaN                  NaN
# 96             1.0000 ± 0.0000        velocity   NaN                  NaN
# 100            0.1953 ± 0.3964        velocity   NaN                  NaN
# 104            1.0000 ± 0.0000        velocity   NaN                  NaN
#
#      mid_level_goal_repeat eval/episode_distance_to_end  \
# 97                     NaN              2.5859 ± 4.1317
# 101                    NaN             10.1562 ± 2.0480
# 105                    NaN              2.1328 ± 4.4902
# 96                     NaN              0.0000 ± 0.0000
# 100                    NaN              2.0625 ± 2.8000
# 104                    NaN              0.0000 ± 0.0000
#
#     eval/episode_maze_column eval/episode_maze_row
# 97           1.4766 ± 0.8288       2.0156 ± 1.1179
# 101          3.2188 ± 0.4667       4.1719 ± 0.8848
# 105          1.3828 ± 0.9364       1.6406 ± 1.0057
# 96           1.0000 ± 0.0000       1.0000 ± 0.0000
# 100          1.7734 ± 0.5033       1.8203 ± 0.4749
# 104          1.0000 ± 0.0000       1.0000 ± 0.0000

# %% [markdown]
# ## HMA2 Performance

# %%
goal_importance_vals = [None, 'discrete', 'continuous']
action_repeats = [1.0, 5.0]
reward_types = ['dense', 'sparse']

for k, environment in enumerate(benchmark_task_data['environment'].unique()):

    fig, axs = plt.subplots(2, 3, figsize=(15, 8))
    fig.suptitle(environment.capitalize(), x=-0.0, y=1.03, weight='bold', ha='left', va='top', fontsize=16)
    # Underline the title using a line
    fig.subplots_adjust(top=0.88)  # Adjust the top of the subplots to make space for the title
    line_x = jp.linspace(0, 1, 100)
    line_y = jp.ones(100) * 0.99  # Adjust the y-coordinate of the line to match the title position
    plt.plot(line_x, line_y, 'k-', transform=fig.transFigure, clip_on=False)

    plt.tight_layout()

    if environment == 'maze':
        metric = 'eval/episode_distance_to_end'
        ylim = (0, 25)  
        ylabel = 'Maze Progress'
    else:
        metric = 'eval/episode_obstacles_complete'
        ylabel = 'Obstacles Complete'
        if environment == 'gaps':
            ylim = (0, 16)
        else:
            ylim = (0, 10)

    #metric = 'eval/episode_reward'

    for i, reward_type in enumerate(reward_types):

        if environment == 'gaps':
            ylim = (0, 16)
        
        
        df = get_benchmark_data(environment, reward_type, True)
        df = df[df.model != 'hma3'] 
        df['plot_data'] = df['modelpath'].apply(lambda x: get_training_metrics(x))

        flat = df[df.model == 'flat']
        hma2 = df[df.model == 'hma2']

        for j, goal_importance in enumerate(goal_importance_vals):
            
            if goal_importance is None:
                t = 'No importance weighting'
            elif goal_importance == 'discrete':
                t = 'Binary importance weighting'
            else:
                t = 'Continuous importance weighting'

            ax = axs[i, j]
            ax.set_title(t if i==0 else None)
            if j == 0:
                ax.annotate(reward_type + ' reward', xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
                    xycoords=ax.yaxis.label, textcoords='offset points',
                    size='large', ha='right', va='center', rotation='horizontal')

            if pd.isna(goal_importance):
                ax_data = hma2[hma2.goal_importance.isna()]
            else:
                ax_data = hma2[hma2.goal_importance == goal_importance]
                        
            plot(
                data=flat.plot_data.iloc[0], 
                metric=metric, 
                error='std', 
                label=f"baseline", 
                err_label = None, 
                xlabel = None, 
                ylabel = None,
                xlim = (0, 50_000_000),
                ylim = (0,10),
                ax = ax
                )
            
            for action_repeat in action_repeats:
                try:
                    plot_data = ax_data[ax_data.action_repeat == action_repeat]['plot_data'].iloc[0]
                except:
                    continue

                plot(
                    data=plot_data, 
                    metric=metric, 
                    error='std', 
                    label=f"goal_repeat = {action_repeat}", 
                    err_label = None, 
                    xlabel = 'Timesteps' if i==1 else None, 
                    ylabel = ylabel if j==0 else None,
                    xlim = (0, 50_000_000),
                    ylim = ylim,
                    ax = ax
                    )
                
plt.legend(loc='upper right', bbox_to_anchor=(1, -0.2))

# %%
goal_importance_vals = [None, 'discrete', 'continuous']
action_repeats = [1.0, 5.0]
reward_types = ['dense', 'sparse']
model = 'mid_level'
mid_level_data = data[data.model == 'mid_level']


fig, axs = plt.subplots(1, 3, figsize=(15, 4))
plt.tight_layout()

for i, no_root_goals in enumerate([False]):

 
    df = mid_level_data[mid_level_data['no_root_goals'] == no_root_goals]
    df['plot_data'] = df['modelpath'].apply(lambda x: get_training_metrics(x))

    for j, goal_importance in enumerate(goal_importance_vals):

        ax = axs[j]
        ax.set_title(f"Goal Feature Space = {goal_importance}" if i==0 else None)

        if pd.isna(goal_importance):
            ax_data = df[df.goal_importance.isna()]
        else:
            ax_data = df[df.goal_importance == goal_importance]
    
        
        for action_repeat in action_repeats:
            
            plot_data = ax_data[ax_data.action_repeat == action_repeat]['plot_data'].iloc[0]

            plot(
                data=plot_data, 
                metric='eval/episode_reward', 
                error='std', 
                label=f"Low level goal repeat = {action_repeat}", 
                err_label = None, 
                xlabel = 'Timesteps' if i==1 else None, 
                ylabel = 'Intrinsic reward' if j==0 else None,
                xlim = (0, 150_000_000),
                ylim = (0, 6500),
                ax = ax
                )
plt.legend(loc='upper right', bbox_to_anchor=(1, -0.1))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 30
#      25             ax_data = df[df.goal_importance == goal_importance]
#      28         for action_repeat in action_repeats:
# ---> 30             plot_data = ax_data[ax_data.action_repeat == action_repeat]['plot_data'].iloc[0]
#      32             plot(
#      33                 data=plot_data,
#      34                 metric='eval/episode_reward',
#    (...)
#      42                 ax = ax
#      43                 )
#      44 plt.legend(loc='upper right', bbox_to_anchor=(1, -0.1))
#
# File ~/mambaforge/envs/msc-thesis-hpc/lib/python3.11/site-packages/pandas/core/indexing.py:1103, in _LocationIndexer.__getitem__(self, key)
#    1100 axis = self.axis or 0
#    1102 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1103 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~/mambaforge/envs/msc-thesis-hpc/lib/python3.11/site-packages/pandas/core/indexing.py:1656, in _iLocIndexer._getitem_axis(self, key, axis)
#    1653     raise TypeError("Cannot index by location index with a non-integer key")
#    1655 # validate the location
# -> 1656 self._validate_integer(key, axis)
#    1658 return self.obj._ixs(key, axis=axis)
#
# File ~/mambaforge/envs/msc-thesis-hpc/lib/python3.11/site-packages/pandas/core/indexing.py:1589, in _iLocIndexer._validate_integer(self, key, axis)
#    1587 len_axis = len(self.obj._get_axis(axis))
#    1588 if key >= len_axis or key < -len_axis:
# -> 1589     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
mid_level_data[(mid_level_data.no_root_goals == False) & (mid_level_data.action_repeat == 1.0)].head(50)
# Out:
#                      date      model environment  model_variant_id  \
# 4   08/26 17:10:34.670348  mid_level         hma                 0
# 9   08/30 16:28:46.549897  mid_level         hma                 4
# 13  08/26 18:04:48.225351  mid_level         hma                 8
#
#                                             modelpath position_goals  \
# 4   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 9   /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
# 13  /nfs/nhome/live/aoomerjee/MSc-Thesis/hct/train...           True
#
#    velocity_goals goal_dist distance_reward goal_importance  eval/walltime  \
# 4            None  relative        relative            None    1081.225802
# 9            None  relative        relative      continuous    1123.895701
# 13           None  relative        relative        discrete    1523.841544
#
#      training/sps  training/walltime training/entropy_loss  \
# 4    78817.070935        1941.663608            -0.3744499
# 9   172243.928040         900.788062           -0.44382352
# 13   50586.240453        2987.147311            -0.4385764
#
#    training/policy_loss training/total_loss training/v_loss  \
# 4          -0.008241062           3780.5222       3780.9048
# 9          -0.013898773           1571.7152        1572.173
# 13         -0.016082011           1173.1804       1173.6351
#
#     eval/episode_cumulative_final_goal_dist  eval/episode_cumulative_return  \
# 4                                505.678772                    12837.914062
# 9                                146.928543                     3488.759277
# 13                              9788.000977                   261558.890625
#
#    eval/episode_goal_dist eval/episode_goals_reached  \
# 4         4.4560 ± 1.5512            0.0000 ± 0.0000
# 9         2.1484 ± 1.4141            0.0000 ± 0.0000
# 13        2.4561 ± 2.3978            0.0316 ± 0.1739
#
#    eval/episode_is_unhealthy   eval/episode_reward  eval/episode_weight  \
# 4            0.0234 ± 0.1513  5671.3887 ± 432.0966              12344.0
# 9            0.0234 ± 0.1513  2783.3799 ± 341.5134              12247.0
# 13           0.0391 ± 0.1937  3175.4744 ± 445.3770              12596.0
#
#    eval/avg_episode_length  eval/epoch_eval_time      eval/sps  \
# 4     3478.8906 ± 202.4320             26.910636  16647.692641
# 9     3452.0391 ± 312.0483             28.100485  15942.785551
# 13    3404.1953 ± 365.6247             38.278903  11703.574534
#
#     low_level_modelpath  action_repeat no_root_goals  low_level_goal_repeat  \
# 4                   0.0            1.0         False                    1.0
# 9                   1.0            1.0         False                    1.0
# 13                  2.0            1.0         False                    1.0
#
#    reward_type task_information eval/episode_obstacles_complete  \
# 4          NaN              NaN                             NaN
# 9          NaN              NaN                             NaN
# 13         NaN              NaN                             NaN
#
#    eval/episode_task_complete reward_movement  mid_level_modelpath  \
# 4                         NaN             NaN                  NaN
# 9                         NaN             NaN                  NaN
# 13                        NaN             NaN                  NaN
#
#     mid_level_goal_repeat eval/episode_distance_to_end  \
# 4                     NaN                          NaN
# 9                     NaN                          NaN
# 13                    NaN                          NaN
#
#    eval/episode_maze_column eval/episode_maze_row
# 4                       NaN                   NaN
# 9                       NaN                   NaN
# 13                      NaN                   NaN

# %%
goal_importance_vals = [None, 'discrete', 'continuous']
action_repeats = [1.0, 5.0]
reward_types = ['dense', 'sparse']
model = 'hma3'

for k, environment in enumerate(benchmark_task_data['environment'].unique()):

    fig, axs = plt.subplots(2, 3, figsize=(15, 8))
    fig.suptitle(environment.capitalize(), x=-0.0, y=1.03, weight='bold', ha='left', va='top', fontsize=16)
    # Underline the title using a line
    fig.subplots_adjust(top=0.88)  # Adjust the top of the subplots to make space for the title
    line_x = jp.linspace(0, 1, 100)
    line_y = jp.ones(100) * 0.99  # Adjust the y-coordinate of the line to match the title position
    plt.plot(line_x, line_y, 'k-', transform=fig.transFigure, clip_on=False)
    plt.tight_layout()


    if environment == 'maze':
        metric = 'eval/episode_distance_to_end'
        ylim = (0, 25)  
        ylabel = 'Maze Progress'
    else:
        metric = 'eval/episode_obstacles_complete'
        ylabel = 'Obstacles Complete'
        if environment == 'gaps':
            ylim = (0, 16)
        else:
            ylim = (0, 10)

    #metric = 'eval/episode_reward'

    for i, reward_type in enumerate(reward_types):

        if environment == 'gaps':
            ylim = (0, 16)
        
        
        df = get_benchmark_data(environment, reward_type, True)
        df['plot_data'] = df['modelpath'].apply(lambda x: get_training_metrics(x))

        flat = df[df.model == 'flat']
        hma2 = df[(df.model == 'hma3') & (df.no_root_goals == False) & (df.low_level_goal_repeat == 1.0) & (df.state == 'below') & (df.goal_dist == 'relative')]

        for j, goal_importance in enumerate(goal_importance_vals):

            if goal_importance is None:
                t = 'No importance weighting'
            elif goal_importance == 'discrete':
                t = 'Binary importance weighting'
            else:
                t = 'Continuous importance weighting'
                
            ax = axs[i, j]
            ax.set_title(t if i==0 else None)
            if j == 0:
                ax.annotate(reward_type, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
                    xycoords=ax.yaxis.label, textcoords='offset points',
                    size='large', ha='right', va='center', rotation='horizontal')

            if pd.isna(goal_importance):
                ax_data = hma2[hma2.goal_importance.isna()]
            else:
                ax_data = hma2[hma2.goal_importance == goal_importance]
                        
            plot(
                data=flat.plot_data.iloc[0], 
                metric=metric, 
                error='std', 
                label=f"baseline", 
                err_label = None, 
                xlabel = None, 
                ylabel = None,
                xlim = (0, 50_000_000),
                ylim = (0,10),
                ax = ax
                )
            
            for action_repeat in action_repeats:
                
                plot_data = ax_data[ax_data.action_repeat == action_repeat]['plot_data'].iloc[0]

                plot(
                    data=plot_data, 
                    metric=metric, 
                    error='std', 
                    label=f"goal_repeat = {action_repeat}", 
                    err_label = None, 
                    xlabel = 'Timesteps' if i==1 else None, 
                    ylabel = ylabel if j==0 else None,
                    xlim = (0, 50_000_000),
                    ylim = ylim,
                    ax = ax
                    )
plt.legend(loc='upper right', bbox_to_anchor=(1, -0.2))

# %%
goal_importance_vals = [None, 'discrete', 'continuous']
action_repeats = [1.0, 5.0]
reward_types = ['dense', 'sparse']
model = 'hma3'

for k, environment in enumerate(benchmark_task_data['environment'].unique()):

    fig, axs = plt.subplots(2, 3, figsize=(15, 8))
    fig.suptitle(environment.capitalize(), x=-0.0, y=1.03, weight='bold', ha='left', va='top', fontsize=16)
    # Underline the title using a line
    fig.subplots_adjust(top=0.88)  # Adjust the top of the subplots to make space for the title
    line_x = jp.linspace(0, 1, 100)
    line_y = jp.ones(100) * 0.99  # Adjust the y-coordinate of the line to match the title position
    plt.plot(line_x, line_y, 'k-', transform=fig.transFigure, clip_on=False)
    plt.tight_layout()


    if environment == 'maze':
        metric = 'eval/episode_distance_to_end'
        ylim = (0, 25)  
        ylabel = 'Maze Progress'
    else:
        metric = 'eval/episode_obstacles_complete'
        ylabel = 'Obstacles Complete'
        if environment == 'gaps':
            ylim = (0, 16)
        else:
            ylim = (0, 10)

    #metric = 'eval/episode_reward'

    for i, reward_type in enumerate(reward_types):

        if environment == 'gaps':
            ylim = (0, 16)
        
        
        df = get_benchmark_data(environment, reward_type, True)
        df['plot_data'] = df['modelpath'].apply(lambda x: get_training_metrics(x))

        flat = df[df.model == 'flat']
        hma2 = df[(df.model == 'hma3') & (df.no_root_goals == False) & (df.low_level_goal_repeat == 1.0) & (df.state == 'below') & (df.goal_dist == 'absolute')]

        for j, goal_importance in enumerate(goal_importance_vals):

            if goal_importance is None:
                t = 'No importance weighting'
            elif goal_importance == 'discrete':
                t = 'Binary importance weighting'
            else:
                t = 'Continuous importance weighting'
                
            ax = axs[i, j]
            ax.set_title(t if i==0 else None)
            if j == 0:
                ax.annotate(reward_type, xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
                    xycoords=ax.yaxis.label, textcoords='offset points',
                    size='large', ha='right', va='center', rotation='horizontal')

            if pd.isna(goal_importance):
                ax_data = hma2[hma2.goal_importance.isna()]
            else:
                ax_data = hma2[hma2.goal_importance == goal_importance]
                        
            plot(
                data=flat.plot_data.iloc[0], 
                metric=metric, 
                error='std', 
                label=f"baseline", 
                err_label = None, 
                xlabel = None, 
                ylabel = None,
                xlim = (0, 50_000_000),
                ylim = (0,10),
                ax = ax
                )
            
            for action_repeat in action_repeats:
                
                plot_data = ax_data[ax_data.action_repeat == action_repeat]['plot_data'].iloc[0]

                plot(
                    data=plot_data, 
                    metric=metric, 
                    error='std', 
                    label=f"goal_repeat = {action_repeat}", 
                    err_label = None, 
                    xlabel = 'Timesteps' if i==1 else None, 
                    ylabel = ylabel if j==0 else None,
                    xlim = (0, 50_000_000),
                    ylim = ylim,
                    ax = ax
                    )
plt.legend(loc='upper right', bbox_to_anchor=(1, -0.2))

# %% [markdown]
# ## Low level discrete analysis

# %%
from hct.envs.tools import node_dist, world_to_relative, world_to_egocentric
from brax import base
import numpy as np


modelpath = Path(f"{hma_filepath}/low_level/runs/2")

def analyse_skills(modelpath):
    env = load(f"{modelpath}/env")
    exp_data = load(f"{modelpath}/data")
    data = exp_data['data']

    states = data.nstate
    if hasattr(env, 'low_level_env'):
        vmap_rel = jax.vmap(jax.vmap(world_to_egocentric))
        vmap_abstract = jax.vmap(jax.vmap(env.abstract_state))
        relative_states = vmap_abstract(vmap_rel(states.pipeline_state))
    else:
        vmap_rel = jax.vmap(jax.vmap(world_to_relative, in_axes=(0, None)), in_axes=(0, None))
        x, xd = vmap_rel(states.pipeline_state, env)
        relative_states = states.pipeline_state.replace(x=x, xd=xd)
    goals = states.info['goal']
    goal_count = states.info['goal_count']
    importance = goals.importance

    node_dist_in_axes = (None, 0, 0, 0, 0, None, None, 0)
    node_dist_vmap = jax.vmap(jax.vmap(node_dist, in_axes=node_dist_in_axes), in_axes=node_dist_in_axes)
    node_goal_dist = node_dist_vmap(
        env, 
        relative_states.x,
        relative_states.xd,
        goals.x_rel,
        goals.xd_rel,
        False,
        False,
        importance
    )               
    
    def first_last_indices_values(A, B):
        A = A.flatten()
        B = B.reshape(-1, B.shape[-1])
        
        mask = jp.concatenate((jp.array([True]), A[1:] != A[:-1])) | jp.concatenate((A[:-1] != A[1:], jp.array([True])))
        # find the indices of True values
        true_indices = jp.where(mask)[0]

        # find the differences between consecutive True indices
        diffs = jp.diff(true_indices)

        # find the start and end indices of consecutive True sequences
        start_indices = jp.where(diffs != 1)[0] + 1
        end_indices = jp.where(diffs != 1)[0]

        # add the start and end indices of the array
        start_indices = jp.insert(start_indices, 0, 0)
        end_indices = jp.append(end_indices, len(true_indices) - 1)

        # set the middle True values to False
        for start, end in zip(start_indices, end_indices):
            if end - start >= 2:
                middle_indices = true_indices[start:end + 1][1:-1]
                mask = mask.at[middle_indices].set(False)


        result = B[mask]
        return result.reshape(-1, 2, B.shape[-1])
    

    
    dist_changes = first_last_indices_values(goal_count, node_goal_dist)
    importance_per_goal = first_last_indices_values(goal_count, importance.squeeze())[:, 0, :]
    importance_norm_per_goal = first_last_indices_values(goal_count, jp.linalg.norm(importance.squeeze(), axis=2, keepdims=True))[:, 0, :]
    control = (dist_changes[:, 0, :]/((dist_changes[:, 1, :]) + 1e-10))

    return {
        'dist_changes': dist_changes,
        'importance': importance_per_goal, 
        'importance_norm_per_goal': importance_norm_per_goal.squeeze(), 
        'control': control}

out = analyse_skills(modelpath)
#print([i.shape for i in out])



# root goals

root_goal_indices = jp.argwhere(out['importance'][:, 0]==1.0).squeeze()
x = jp.round(out['importance_norm_per_goal'][root_goal_indices] ** 2) 
y = out['control'][root_goal_indices, 0]
sns.boxplot(x=np.asarray(x), y=np.asarray(y))
plt.xlabel('Goal feature space size')
plt.ylabel('None controllability')
plt.show()

fig, axs = plt.subplots(1, 2, figsize=(15, 4))
plt.tight_layout()

# upper limb goals
ax = axs[0]
idx = range(1, 9)
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx])
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

goal_indices_root = jp.argwhere((importance==1.0) * (importance_root==1.0)).squeeze()
goal_indices_no_root = jp.argwhere((importance==1.0) * (importance_root==0.0)).squeeze()

x = jp.round(x[goal_indices_root] ** 2) 
y = control[goal_indices_root]
data = [control[goal_indices_root], control[goal_indices_no_root]]

sns.boxplot(data=data, ax=ax)
ax.set_ylabel('Node controllability')
ax.set_xticks(ticks=[0, 1], labels=['Root node goal', 'No root node goal'])
ax.set_ylim(0, 110)

# lower limb goals
ax = axs[1]

idx = [2,4,6,8]
#idx = [2,4,6,8]
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx])
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))


goal_indices_root = jp.argwhere((importance==1.0) * (importance_root==1.0)).squeeze()
goal_indices_no_root = jp.argwhere((importance==1.0) * (importance_root==0.0)).squeeze()

x = jp.round(x[goal_indices_root] ** 2) 
y = control[goal_indices_root]
data = [control[goal_indices_root], control[goal_indices_no_root]]
'''
unique_x= jp.unique(x)
means = jp.array([jp.mean(y[jp.where(x==ux)]) for ux in unique_x])
stds = jp.array([jp.std(y[jp.where(x==ux)]) for ux in unique_x])
stderrs = stds / jp.sqrt(jp.array([len(y[jp.where(x==ux)]) for ux in unique_x]))'''


sns.boxplot(data, ax=ax)
ax.set_ylabel(None)
ax.set_xticks(ticks=[0, 1], labels=['Root node goal', 'No root node goal'])
ax.set_ylim(0, 110)
ax.set_title('Lower limb nodes')



#plt.scatter(jp.repeat(out['importance_norm_per_goal'], 4), jp.concatenate([out['control'][:, 2], out['control'][:, 4], out['control'][:, 6], out['control'][:, 8]] ), s=1)
# Out:
# Text(0.5, 1.0, 'Lower limb nodes')

# %%
fig, axs = plt.subplots(2,2, figsize=(15, 8))
plt.tight_layout()
#print([i.shape for i in out])


# low level discrete 
ax = axs[0, 0]
modelpath = Path(f"{hma_filepath}/low_level/runs/2")
out = analyse_skills(modelpath)
root_goal_indices = jp.argwhere(out['importance'][:, 0]==1.0).squeeze()
x = jp.round(out['importance_norm_per_goal'][root_goal_indices] ** 2) 
y = out['control'][root_goal_indices, 0]
sns.boxplot(x=np.asarray(x), y=np.asarray(y), ax=ax)
ax.set_xlabel(None)
ax.set_ylabel('None controllability')
ax.set_title("Goal feature space = discrete")
ax.annotate('Low Level Skill Layer', xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
    xycoords=ax.yaxis.label, textcoords='offset points',
    size='large', ha='right', va='center', rotation='horizontal')


# mid level discrete
ax = axs[1, 0]
modelpath = Path(f"{hma_filepath}/mid_level/runs/8")
out = analyse_skills(modelpath)
root_goal_indices = jp.argwhere(out['importance'][:, 0]==1.0).squeeze()
x = jp.round(out['importance_norm_per_goal'][root_goal_indices] ** 2) 
y = out['control'][root_goal_indices, 0]
sns.boxplot(x=np.asarray(x), y=np.asarray(y), ax=ax)
ax.set_xlabel('Goal feature space size')
ax.set_ylabel('None controllability')
ax.set_ylim(0, 6)
ax.annotate('Mid Level Skill Layer', xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
    xycoords=ax.yaxis.label, textcoords='offset points',
    size='large', ha='right', va='center', rotation='horizontal')


#low level continuous
ax = axs[0, 1]
modelpath = Path(f"{hma_filepath}/low_level/runs/1")
out = analyse_skills(modelpath)
root_goal_indices = jp.argwhere(out['importance'][:, 0] > 0.8).squeeze()

x = out['importance_norm_per_goal'][root_goal_indices]
y = out['control'][root_goal_indices, 0] / out['importance'][root_goal_indices, 0]

bins = jp.arange(jp.min(x), jp.max(x)+0.01, 0.05)
plotdata = pd.DataFrame({'x': x, 'y': y})
plotdata['x_bin'] = np.digitize(plotdata['x'], bins)
mean_y_per_bin = plotdata.groupby('x_bin')['y'].mean()
std_y_per_bin = plotdata.groupby('x_bin')['y'].std()
x = np.asarray(bins)
y = np.asarray(mean_y_per_bin.to_numpy())

sns.lineplot(x=x[:len(y)], y=y)
ax.fill_between(x[:len(y)], y - std_y_per_bin, y + std_y_per_bin, color='b', alpha=0.2)
ax.set_ylim(0, 6)
ax.set_title("Goal feature space = continuous")

#low level continuous
ax = axs[1, 1]
modelpath = Path(f"{hma_filepath}/mid_level/runs/4")
out = analyse_skills(modelpath)
root_goal_indices = jp.argwhere(out['importance'][:, 0] > 0.8).squeeze()
x = out['importance_norm_per_goal'][root_goal_indices]
y = out['control'][root_goal_indices, 0] / out['importance'][root_goal_indices, 0]
sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4}, ax=ax)
ax.set_xlabel('Goal feature space norm')
ax.set_ylim(0, 6)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 63
#      61 ax = axs[1, 1]
#      62 modelpath = Path(f"{hma_filepath}/mid_level/runs/4")
# ---> 63 out = analyse_skills(modelpath)
#      64 root_goal_indices = jp.argwhere(out['importance'][:, 0] > 0.8).squeeze()
#      65 x = out['importance_norm_per_goal'][root_goal_indices]
#
# Cell In[9], line 10, in analyse_skills(modelpath)
#       8 def analyse_skills(modelpath):
#       9     env = load(f"{modelpath}/env")
# ---> 10     exp_data = load(f"{modelpath}/data")
#      11     data = exp_data['data']
#      13     states = data.nstate
#
# File ~/MSc-Thesis/hct/io/model.py:9, in load(path)
#       8 def load(path: str) -> Any:
# ----> 9   with epath.Path(path).open('rb') as fin:
#      10     buf = fin.read()
#      11   return dill.loads(buf)
#
# File ~/mambaforge/envs/msc-thesis-hpc/lib/python3.11/site-packages/etils/epath/gpath.py:226, in _GPath.open(self, mode, encoding, errors, **kwargs)
#     222 if kwargs:
#     223   raise NotImplementedError(
#     224       f'kwargs {list(kwargs)}` not supported in `open()`.'
#     225   )
# --> 226 gfile = self._backend.open(self._path_str, mode)
#     227 gfile = typing.cast(typing.IO[Union[str, bytes]], gfile)
#     228 return gfile
#
# File ~/mambaforge/envs/msc-thesis-hpc/lib/python3.11/site-packages/etils/epath/backend.py:104, in _OsPathBackend.open(self, path, mode)
#     102 else:
#     103   encoding = 'utf-8'
# --> 104 return open(path, mode, encoding=encoding)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/nfs/nhome/live/aoomerjee/MSc-Thesis/hct/training/hyperparam_sweeps_v2/hma/mid_level/runs/4/data'

# %%
fig, axs = plt.subplots(2,2, figsize=(15, 8))
plt.tight_layout()
#print([i.shape for i in out])


# low level discrete 
ax = axs[0, 0]
modelpath = Path(f"{hma_filepath}/low_level/runs/2")
out = analyse_skills(modelpath)

idx = range(1, 9)
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx])
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

goal_indices_root = jp.argwhere((importance==1.0) * (importance_root==1.0)).squeeze()
goal_indices_no_root = jp.argwhere((importance==1.0) * (importance_root==0.0)).squeeze()

x = jp.round(x[goal_indices_root] ** 2) 
y = control[goal_indices_root]
data = [control[goal_indices_root], control[goal_indices_no_root]]

sns.boxplot(data=data, ax=ax)
ax.set_ylabel('Node controllability')
ax.set_xticks(ticks=[0, 1], labels=['Root node goal', 'No root node goal'])
ax.set_ylim(0, 110)
ax.set_title("Goal feature space = discrete")
ax.annotate('Low Level Skill Layer', xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
    xycoords=ax.yaxis.label, textcoords='offset points',
    size='large', ha='right', va='center', rotation='horizontal')


# mid level discrete
ax = axs[1, 0]
modelpath = Path(f"{hma_filepath}/mid_level/runs/8")
out = analyse_skills(modelpath)

idx = range(1, 9)
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx])
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

goal_indices_root = jp.argwhere((importance==1.0) * (importance_root==1.0)).squeeze()
goal_indices_no_root = jp.argwhere((importance==1.0) * (importance_root==0.0)).squeeze()

x = jp.round(x[goal_indices_root] ** 2) 
y = control[goal_indices_root]
data = [control[goal_indices_root], control[goal_indices_no_root]]

sns.boxplot(data=data, ax=ax)
ax.set_ylabel('Node controllability')
ax.set_xticks(ticks=[0, 1], labels=['Root node goal', 'No root node goal'])
ax.set_ylim(0, 10)

ax.annotate('Mid Level Skill Layer', xy=(0, 0.5), xytext=(-ax.yaxis.labelpad - 5, 0),
    xycoords=ax.yaxis.label, textcoords='offset points',
    size='large', ha='right', va='center', rotation='horizontal')


#low level continuous
ax = axs[0, 1]
modelpath = Path(f"{hma_filepath}/low_level/runs/1")
out = analyse_skills(modelpath)
idx = range(1, 9)
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx]) 
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

ind = jp.argwhere((jp.abs(importance).squeeze()) >0.9)

x = jp.abs(importance_root[ind])
y = control[ind] / importance[ind]

sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4}, ax=ax)

ax.set_ylim(0, 6)
ax.set_title("Goal feature space = continuous")

#mid level continuous
ax = axs[1, 1]
modelpath = Path(f"{hma_filepath}/mid_level/runs/4")
out = analyse_skills(modelpath)
idx = range(1, 5)

x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx]) 

dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

ind = jp.argwhere((jp.abs(importance).squeeze()) >0.8)

x = jp.abs(importance_root[ind])
y = control[ind] / importance[ind]
print(importance)
print(len(y<0.05)/len(y))

sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4}, ax=ax)
ax.set_xlabel('Goal feature space norm')
ax.set_ylim(0, 6)
# Out:
# [-0.2406  0.8214  0.5597 ... -0.7574 -0.1446  0.4093]
# 1.0
# (0.0, 6.0)

# %%
from hct.envs.tools import node_dist, world_to_relative, world_to_egocentric
from brax import base
import numpy as np


modelpath = Path(f"{hma_filepath}/low_level/runs/1")


out = analyse_skills(modelpath)
#print([i.shape for i in out])

# root goals
root_goal_indices = jp.argwhere(out['importance'][:, 0] > 0).squeeze()
x = out['importance_norm_per_goal'][root_goal_indices]
y = out['control'][root_goal_indices, 0] / out['importance'][:, 0]
sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4})
plt.xlabel('Goal feature space norm')
plt.ylabel('Root node controllability')
plt.ylim(0, 20)
plt.show()


# upper_limb goals
idx = [1,3,5,7]
#idx = [2,4,6,8]
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx]) 
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

ind = jp.argwhere((jp.abs(importance).squeeze()) >0.9)

x = jp.abs(importance_root[ind])
y = control[ind] / importance[ind]


sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4})
plt.ylabel('Upper limb node controllability')

plt.ylim(0, 20)
plt.show()

# lower_limb goals
#idx = [1,3,5,7]
idx = [2,4,6,8]
x = jp.tile(out['importance_norm_per_goal'], len(idx))
control = jp.concatenate([out['control'][:, i] for i in idx])
dist_changes = jp.concatenate([out['dist_changes'][:, :, i] for i in idx])

importance = jp.concatenate([out['importance'][:, i] for i in idx])
importance_root = jp.tile(out['importance'][:, 0], len(idx))

ind = jp.argwhere((jp.abs(importance).squeeze()) >0.9)

x = jp.abs(importance_root[ind])
y = control[ind] / importance[ind]


sns.regplot(x=x, y=y, lowess=True, line_kws={'color': 'red'}, scatter_kws={'s': 0.4})
plt.ylabel('Upper limb node controllability')

plt.ylim(0, 20)
plt.show()

# %%
def analyse_hurdlesgaps(modelpath):
    fig, axs = plt.subplots(3,1, figsize=(15,9))
    env = load(f"{modelpath}/env")
    exp_data = load(f"{modelpath}/data")
    data = exp_data['data']

    task = modelpath.parent.parent.parent.name
    
    obstacle_sizes = [0.24, 0.23, 0.22, 0.34, 0.24, 0.34, 0.23, 0.24, 0.39, 0.38, 0.29, 0.39, 0.39, 0.36, 0.3, 0.36, 0.34, 0.3, 0.36, 0.31]
    obstacle_coords = [2.48, 4.74, 7.08, 9.2, 11.68, 14.44, 16.54, 18.4, 20.76, 23.58, 26.26, 28.44, 31.26, 33.28, 35.92, 38.56, 40.56, 43.06, 45.42, 47.96]

    if task == 'maze':
        obstacle_coords = np.arange(0, 23)
        lim = 22
    else:
        obstacle_coords = jp.array(obstacle_coords) - jp.array(obstacle_sizes)
        lim = 45

    def plot(idx, ax):
        if task == 'hurdles':
            y_sizes = obstacle_sizes[0::2]
            obstacle_completion_coords = obstacle_coords[0::2]
            
        states = data.nstate

        actions = data.action
        
        importance = jax.vmap(jax.vmap(env.get_low_level_goal))(actions, states.pipeline_state).importance
        importance = importance.reshape(-1, *importance.shape[2:]).squeeze()[:, idx]

        if type(idx) is list:
            importance = jp.mean(importance, axis=-1)

        if task == 'maze':
            yvals = states.metrics['distance_to_end']
            yvals = 22 - yvals.flatten()
            bins = jp.arange(0, 23)
        else:
            yvals = states.pipeline_state.x.pos[..., 0, 1]
            yvals = yvals.reshape(-1, *yvals.shape[2:])
            bins = jp.arange(0, jp.max(yvals)+0.3, 0.3)

        x = yvals
        y = importance
        plotdata = pd.DataFrame({'x': x, 'y': y})


        plotdata['x_bin'] = np.digitize(plotdata['x'], bins)
        mean_y_per_bin = plotdata.groupby('x_bin')['y'].mean()

        x = np.asarray(bins)
        y = np.asarray(mean_y_per_bin.to_numpy())

        if type(idx) is not list:
            c = 'C0'
        elif idx[0] == 1:
            c = 'C1'
        else:
            c = 'C2'

        sns.lineplot(x=x[:len(y)], y=y, ax=ax, color=c)
        for i in obstacle_coords:
            ax.axvline(x=i, color='r', linestyle='--', linewidth=0.5)
    
        ax.set_ylim(0, 1)
        ax.set_xlim(0, lim)


    plot(0, axs[0])
    plot([1,3,5,7], axs[1])
    plot([2,4,6,8], axs[2])



    
    plt.show()

plt.title('Hurdles')
modelpath = Path(f"{hurdles_filepath}/hma2/runs/32")
analyse_hurdlesgaps(modelpath)

modelpath = Path(f"{hurdles_filepath}/hma2/runs/16")
analyse_hurdlesgaps(modelpath)

modelpath = Path(f"{gaps_filepath}/hma2/runs/32")
analyse_hurdlesgaps(modelpath)

modelpath = Path(f"{gaps_filepath}/hma2/runs/16")
analyse_hurdlesgaps(modelpath)

modelpath = Path(f"{maze_filepath}/hma2/runs/32")
analyse_hurdlesgaps(modelpath)

modelpath = Path(f"{maze_filepath}/hma2/runs/16")
analyse_hurdlesgaps(modelpath)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 80
#      78 plt.title('Hurdles')
#      79 modelpath = Path(f"{hurdles_filepath}/hma2/runs/32")
# ---> 80 analyse_hurdlesgaps(modelpath)
#      82 modelpath = Path(f"{hurdles_filepath}/hma2/runs/16")
#      83 analyse_hurdlesgaps(modelpath)
#
# Cell In[13], line 69, in analyse_hurdlesgaps(modelpath)
#      65     ax.set_ylim(0, 1)
#      66     ax.set_xlim(0, lim)
# ---> 69 plot(0, axs[0])
#      70 plot([1,3,5,7], axs[1])
#      71 plot([2,4,6,8], axs[2])
#
# Cell In[13], line 28, in analyse_hurdlesgaps.<locals>.plot(idx, ax)
#      24 states = data.nstate
#      26 actions = data.action
# ---> 28 importance = jax.vmap(jax.vmap(env.get_low_level_goal))(actions, states.pipeline_state).importance
#      29 importance = importance.reshape(-1, *importance.shape[2:]).squeeze()[:, idx]
#      31 if type(idx) is list:
#
#     [... skipping hidden 6 frame]
#
# File ~/MSc-Thesis/hct/envs/hma_env.py:399, in HMA2Env.get_low_level_goal(self, g, state)
#     397   else:
#     398     importance = jp.where(importance > 0, x=1.0, y=0.0)
# --> 399     if self.no_root_goals:
#     400       importance = importance.at[0,0].set(0)
#     401 else:
#
# AttributeError: 'HMA2HurdlesGapsEnv' object has no attribute 'no_root_goals'
